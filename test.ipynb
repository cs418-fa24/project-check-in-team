# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Zip_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
print(df.shape)
df = df[df["City"] == "Chicago"].sort_values(by="RegionName")
df
# Out:
# (20162, 13)
#        RegionID  SizeRank  RegionName RegionType StateName State     City  \
# 7709      84603      7958       60601        zip        IL    IL  Chicago
# 16500     84604     20351       60602        zip        IL    IL  Chicago
# 17177     84605     21722       60603        zip        IL    IL  Chicago
# 17639     84606     22680       60604        zip        IL    IL  Chicago
# 3870      84607      3929       60605        zip        IL    IL  Chicago
# 10927     84608     11930       60606        zip        IL    IL  Chicago
# 3595      84609      3650       60607        zip        IL    IL  Chicago
# 94        84610        99       60608        zip        IL    IL  Chicago
# 300       84611       307       60609        zip        IL    IL  Chicago
# 1605      84612      1636       60610        zip        IL    IL  Chicago
# 2690      84613      2735       60611        zip        IL    IL  Chicago
# ...

# %%
df1 = pd.read_csv("Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
print(df1.shape)
df1 = df1[df1["City"] == "Chicago"].sort_values(by="RegionName")
df1
# Out:
# (26337, 306)
#        RegionID  SizeRank  RegionName RegionType StateName State     City  \
# 7860      84603      7958       60601        zip        IL    IL  Chicago
# 19761     84604     20351       60602        zip        IL    IL  Chicago
# 20936     84605     21722       60603        zip        IL    IL  Chicago
# 21754     84606     22680       60604        zip        IL    IL  Chicago
# 3886      84607      3929       60605        zip        IL    IL  Chicago
# 11770     84608     11930       60606        zip        IL    IL  Chicago
# 3610      84609      3650       60607        zip        IL    IL  Chicago
# 94        84610        99       60608        zip        IL    IL  Chicago
# 300       84611       307       60609        zip        IL    IL  Chicago
# 1612      84612      1636       60610        zip        IL    IL  Chicago
# 2703      84613      2735       60611        zip        IL    IL  Chicago
# ...

# %%
df.iloc[0,:]
# Out:
# RegionID                                   84603
# SizeRank                                    7958
# RegionName                                 60601
# RegionType                                   zip
# StateName                                     IL
# State                                         IL
# City                                     Chicago
# Metro         Chicago-Naperville-Elgin, IL-IN-WI
# CountyName                           Cook County
# BaseDate                              2024-09-30
# 2024-10-31                                  -0.1
# 2024-12-31                                  -0.6
# 2025-09-30                                  -0.7
# Name: 7709, dtype: object

# %%
df1.iloc[0,:].tail(50)
# Out:
# 2020-08-31    371712.346162
# 2020-09-30    372287.219795
# 2020-10-31     372666.21579
# 2020-11-30    372062.057542
# 2020-12-31    370917.108029
# 2021-01-31    370826.159365
# 2021-02-28    371149.304718
# 2021-03-31    371859.488311
# 2021-04-30    371928.036441
# 2021-05-31    371040.431314
# 2021-06-30    369495.494703
# 2021-07-31     368126.33834
# 2021-08-31    367106.880965
# 2021-09-30    366008.955847
# 2021-10-31    365169.714235
# 2021-11-30    365427.020649
# 2021-12-31    367171.486229
# 2022-01-31    369705.226735
# 2022-02-28    372834.261409
# 2022-03-31     376297.76085
# 2022-04-30    379084.816764
# 2022-05-31    378856.227753
# 2022-06-30    377496.353332
# 2022-07-31    374671.352454
# 2022-08-31    371693.208206
# 2022-09-30    367914.494919
# 2022-10-31     364560.87769
# 2022-11-30    362289.450286
# 2022-12-31    359133.489142
# 2023-01-31    353613.829063
# 2023-02-28    347062.615711
# 2023-03-31     340326.91716
# 2023-04-30    335239.675902
# ...
